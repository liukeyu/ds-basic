# %%
# coding: utf-8
import pandas as pd
import csv 


df=pd.read_csv('data/lj.csv',encoding = "gbk",header=None,names=['district','district2','community','apm_type','apm_size','floor','price','url'])
df["numeric_apm_size"]=df.apm_size.str[:-1]
pd.to_numeric(df["numeric_apm_size"])
df.loc[df['community'].str[:2] == '漕溪']
# Out:
#     district district2 community apm_type apm_size   floor  price  \
# 14        徐汇       徐家汇      漕溪大楼     2室0厅      55平  高区/17层   6500
# 37        徐汇       万体馆      漕溪四村     2室1厅      56平   高区/6层   5500
# 45        徐汇       徐家汇      漕溪大楼     2室1厅      54平  高区/14层   6580
# 83        徐汇       万体馆      漕溪二村     2室1厅      50平   低区/6层   5400
# 123       徐汇       徐家汇      漕溪大楼     2室1厅      54平  低区/14层   6800
# 128       徐汇       徐家汇      漕溪大楼     2室0厅      55平  低区/14层   6500
# 212       徐汇       徐家汇      漕溪大楼     2室1厅      54平  中区/14层   6800
# 287       徐汇       万体馆      漕溪三村     2室1厅      56平   中区/4层   6500
# 313       徐汇       万体馆      漕溪三村     2室1厅      50平   高区/5层   6200
#
#                                               url numeric_apm_size
# 14   http://sh.lianjia.com/zufang/shz4051997.html               55
# 37   http://sh.lianjia.com/zufang/shz4122158.html               56
# 45   http://sh.lianjia.com/zufang/shz4109737.html               54
# ...
